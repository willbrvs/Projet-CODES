# %%
from PIL import Image
import numpy as np
from keras.models import Model, load_model
from keras.layers import Input, Dense, LeakyReLU, Conv2D, Conv2DTranspose, Add, Lambda, Flatten, Reshape
from keras.optimizers import Adam
from tensorflow.keras.layers import PReLU
from keras.regularizers import l2
import keras.backend as K
import numpy as np
import glob
from sklearn.model_selection import train_test_split
import os
import matplotlib.pyplot as plt
import heapq
import collections
from typing import List, Dict, Tuple
import tensorflow as tf

# %% [markdown]
# ## Resize, conversion and normalisation des photos

# %% [markdown]
# Fonction de resize, normalisation, conversion en nuances de gris

# %%
def resize_and_convert_to_gray(input_path, size=(128, 128)):
    with Image.open(input_path) as img:
        img = img.resize(size)
        gray_img = img.convert('L')
        gray_img.save("Image_grise_1.png")
        img_array = np.asarray(gray_img, dtype=np.float32) / 255.0
        return img_array.reshape(size[0], size[1], 1)

# %%
def convert_to_gray_and_save(img_array, output_path):

    img_array *= 255.0
    img_array = img_array.clip(0, 255)
    img_gray = Image.fromarray(np.uint8(img_array), 'L')
    img_gray.save(output_path)

    return img_gray

# %% [markdown]
# ## Autoencoder

# %% [markdown]
# Définition de l'autoencoder

# %%
# Taille de l'image d'entrée
input_shape = (128, 128, 1)

# Encoder
encoder_input = Input(shape=input_shape, name="encoder_input")
x = Conv2D(32, (3, 3), padding='same')(encoder_input)
x = LeakyReLU()(x)
x = Conv2D(64, (3, 3), strides=(2, 2), padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(128, (3, 3), strides=(2, 2), padding='same')(x)
x = LeakyReLU()(x)
x = Flatten()(x)
encoder_output = Dense(units=2, name="encoder_output")(x)  # Suppose the latent space has 2 dimensions

encoder = Model(encoder_input, encoder_output, name="encoder_model")
encoder.summary()
# Out:
# Model: "encoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 128, 128, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 128, 32)      320
#
#  leaky_re_lu (LeakyReLU)     (None, 128, 128, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        18496
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  encoder_output (Dense)      (None, 2)                 262146
#
# =================================================================
# Total params: 354818 (1.35 MB)
# Trainable params: 354818 (1.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Définition du decoder

# %%
# Decoder
decoder_input = Input(shape=(2,), name="decoder_input")  # Latent space dimensions
x = Dense(units=32 * 32 * 128)(decoder_input)  # Adjust the units to match the encoder's last Conv2D output shape
x = LeakyReLU()(x)
x = Reshape((32, 32, 128))(x)
x = Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same')(x)
x = LeakyReLU()(x)
x = Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same')(x)
x = LeakyReLU()(x)
decoder_output = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x) # Use sigmoid for normalizing the output between 0 and 1

decoder = Model(decoder_input, decoder_output, name="decoder_model")
decoder.summary()
# Out:
# Model: "decoder_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  dense (Dense)               (None, 131072)            393216
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 131072)            0
#
#  reshape (Reshape)           (None, 32, 32, 128)       0
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 64)        73792
#  anspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 64)        0
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 32)      18464
#  Transpose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128, 128, 32)      0
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 1)       289
#  Transpose)
#
# =================================================================
# Total params: 485761 (1.85 MB)
# Trainable params: 485761 (1.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Création de l'autoencoder à partir de l'encoder et du decoder

# %%
ae_input = Input(shape=input_shape, name="AE_input")
ae_encoder_output = encoder(ae_input)
ae_decoder_output = decoder(ae_encoder_output)

autoencoder = Model(ae_input, ae_decoder_output, name="AE")
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')
autoencoder.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  AE_input (InputLayer)       [(None, 128, 128, 1)]     0
#
#  encoder_model (Functional)  (None, 2)                 354818
#
#  decoder_model (Functional)  (None, 128, 128, 1)       485761
#
# =================================================================
# Total params: 840579 (3.21 MB)
# Trainable params: 840579 (3.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#autoencoder = load_model("autoencoder_model10.keras", safe_mode=False)

# %% [markdown]
# Résumé de l'autoencoder

# %%
autoencoder.summary()
# Out:
# Model: "AE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  AE_input (InputLayer)       [(None, 128, 128, 1)]     0
#
#  encoder_model (Functional)  (None, 2)                 354818
#
#  decoder_model (Functional)  (None, 128, 128, 1)       485761
#
# =================================================================
# Total params: 840579 (3.21 MB)
# Trainable params: 840579 (3.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Création des dataset de train et de test. 80-20%

# %%
image_files = glob.glob('Kodak/*.png')
train_files, test_files = train_test_split(image_files, test_size=0.2, random_state=42)

# %% [markdown]
# Entrainement et sauvegarde du modèle

# %%
# Charger et préparer les images
train_images = np.array([resize_and_convert_to_gray(path) for path in train_files])
test_images = np.array([resize_and_convert_to_gray(path) for path in test_files])

# Entraîner l'autoencoder
autoencoder.fit(train_images, train_images, epochs=50000, batch_size=16, validation_data=(test_images, test_images))
autoencoder.save('autoencoder_model10.keras')
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8643e-05 - val_loss: 0.0636
# Epoch 28172/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6834e-05 - val_loss: 0.0638
# Epoch 28173/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0636e-05 - val_loss: 0.0638
# Epoch 28174/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.9361e-05 - val_loss: 0.0632
# Epoch 28175/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.9858e-05 - val_loss: 0.0634
# Epoch 28176/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.7665e-05 - val_loss: 0.0642
# Epoch 28177/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.9117e-05 - val_loss: 0.0638
# Epoch 28178/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.6779e-05 - val_loss: 0.0633
# Epoch 28179/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.8735e-05 - val_loss: 0.0636
# Epoch 28180/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.7250e-05 - val_loss: 0.0638
# Epoch 28181/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.7629e-05 - val_loss: 0.0634
# Epoch 28182/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.7973e-05 - val_loss: 0.0636
# Epoch 28183/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.5550e-05 - val_loss: 0.0639
# Epoch 28184/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.7698e-05 - val_loss: 0.0636
# Epoch 28185/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6610e-05 - val_loss: 0.0634
# Epoch 28186/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.9985e-05 - val_loss: 0.0635
# Epoch 28187/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5945e-05 - val_loss: 0.0638
# Epoch 28188/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5934e-05 - val_loss: 0.0637
# Epoch 28189/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6147e-05 - val_loss: 0.0634
# Epoch 28190/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6148e-05 - val_loss: 0.0636
# Epoch 28191/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.6264e-05 - val_loss: 0.0638
# Epoch 28192/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6713e-05 - val_loss: 0.0635
# Epoch 28193/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8160e-05 - val_loss: 0.0633
# Epoch 28194/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8681e-05 - val_loss: 0.0637
# Epoch 28195/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.7162e-05 - val_loss: 0.0642
# Epoch 28196/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 3.1530e-05 - val_loss: 0.0641
# Epoch 28197/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 3.2258e-05 - val_loss: 0.0633
# Epoch 28198/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.2420e-05 - val_loss: 0.0637
# Epoch 28199/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.8456e-05 - val_loss: 0.0641
# Epoch 28200/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 4.1527e-05 - val_loss: 0.0633
# Epoch 28201/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.6408e-05 - val_loss: 0.0635
# Epoch 28202/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.0342e-05 - val_loss: 0.0641
# Epoch 28203/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0329e-05 - val_loss: 0.0638
# Epoch 28204/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9979e-05 - val_loss: 0.0632
# Epoch 28205/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0465e-05 - val_loss: 0.0636
# Epoch 28206/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.7275e-05 - val_loss: 0.0641
# Epoch 28207/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4707e-05 - val_loss: 0.0637
# Epoch 28208/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.8629e-05 - val_loss: 0.0633
# Epoch 28209/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.0551e-05 - val_loss: 0.0637
# Epoch 28210/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.6926e-05 - val_loss: 0.0643
# Epoch 28211/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 3.2365e-05 - val_loss: 0.0639
# Epoch 28212/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.8478e-05 - val_loss: 0.0632
# Epoch 28213/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.2073e-05 - val_loss: 0.0637
# Epoch 28214/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.8920e-05 - val_loss: 0.0641
# Epoch 28215/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0321e-05 - val_loss: 0.0635
# Epoch 28216/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6739e-05 - val_loss: 0.0632
# Epoch 28217/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.7572e-05 - val_loss: 0.0638
# Epoch 28218/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6022e-05 - val_loss: 0.0639
# Epoch 28219/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8240e-05 - val_loss: 0.0634
# Epoch 28220/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5185e-05 - val_loss: 0.0633
# Epoch 28221/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5579e-05 - val_loss: 0.0637
# Epoch 28222/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4790e-05 - val_loss: 0.0640
# Epoch 28223/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.4690e-05 - val_loss: 0.0636
# Epoch 28224/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5868e-05 - val_loss: 0.0635
# Epoch 28225/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.4484e-05 - val_loss: 0.0639
# Epoch 28226/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.4057e-05 - val_loss: 0.0638
# Epoch 28227/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4083e-05 - val_loss: 0.0635
# Epoch 28228/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2910e-05 - val_loss: 0.0637
# Epoch 28229/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3442e-05 - val_loss: 0.0637
# Epoch 28230/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2825e-05 - val_loss: 0.0636
# Epoch 28231/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2767e-05 - val_loss: 0.0637
# Epoch 28232/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.2720e-05 - val_loss: 0.0638
# Epoch 28233/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2237e-05 - val_loss: 0.0638
# Epoch 28234/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.2281e-05 - val_loss: 0.0637
# Epoch 28235/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1769e-05 - val_loss: 0.0636
# Epoch 28236/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1829e-05 - val_loss: 0.0636
# Epoch 28237/50000
# 2/2 [==============================] - 0s 40ms/step - loss: 2.2005e-05 - val_loss: 0.0636
# Epoch 28238/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1747e-05 - val_loss: 0.0636
# Epoch 28239/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1578e-05 - val_loss: 0.0637
# Epoch 28240/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1804e-05 - val_loss: 0.0636
# Epoch 28241/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1276e-05 - val_loss: 0.0637
# Epoch 28242/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1177e-05 - val_loss: 0.0637
# Epoch 28243/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1088e-05 - val_loss: 0.0635
# Epoch 28244/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.1111e-05 - val_loss: 0.0636
# Epoch 28245/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.1325e-05 - val_loss: 0.0637
# Epoch 28246/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1025e-05 - val_loss: 0.0636
# Epoch 28247/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0918e-05 - val_loss: 0.0636
# Epoch 28248/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1085e-05 - val_loss: 0.0637
# Epoch 28249/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1005e-05 - val_loss: 0.0637
# Epoch 28250/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.1343e-05 - val_loss: 0.0636
# Epoch 28251/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1092e-05 - val_loss: 0.0636
# Epoch 28252/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1139e-05 - val_loss: 0.0637
# Epoch 28253/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.1241e-05 - val_loss: 0.0637
# Epoch 28254/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0822e-05 - val_loss: 0.0636
# Epoch 28255/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0821e-05 - val_loss: 0.0637
# Epoch 28256/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1270e-05 - val_loss: 0.0637
# Epoch 28257/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0882e-05 - val_loss: 0.0637
# Epoch 28258/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0735e-05 - val_loss: 0.0636
# Epoch 28259/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.0502e-05 - val_loss: 0.0636
# Epoch 28260/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0539e-05 - val_loss: 0.0637
# Epoch 28261/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1040e-05 - val_loss: 0.0636
# Epoch 28262/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0395e-05 - val_loss: 0.0636
# Epoch 28263/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0396e-05 - val_loss: 0.0637
# Epoch 28264/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0381e-05 - val_loss: 0.0637
# Epoch 28265/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.0366e-05 - val_loss: 0.0636
# Epoch 28266/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.0398e-05 - val_loss: 0.0637
# Epoch 28267/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0500e-05 - val_loss: 0.0637
# Epoch 28268/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.0178e-05 - val_loss: 0.0637
# Epoch 28269/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0119e-05 - val_loss: 0.0636
# Epoch 28270/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.0390e-05 - val_loss: 0.0636
# Epoch 28271/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.0512e-05 - val_loss: 0.0637
# Epoch 28272/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0268e-05 - val_loss: 0.0638
# Epoch 28273/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0479e-05 - val_loss: 0.0636
# Epoch 28274/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1570e-05 - val_loss: 0.0637
# Epoch 28275/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2090e-05 - val_loss: 0.0636
# Epoch 28276/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1602e-05 - val_loss: 0.0636
# Epoch 28277/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4962e-05 - val_loss: 0.0637
# Epoch 28278/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7951e-05 - val_loss: 0.0634
# Epoch 28279/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2944e-05 - val_loss: 0.0634
# Epoch 28280/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2442e-05 - val_loss: 0.0637
# Epoch 28281/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4471e-05 - val_loss: 0.0636
# Epoch 28282/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.1903e-05 - val_loss: 0.0637
# Epoch 28283/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2352e-05 - val_loss: 0.0638
# Epoch 28284/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1483e-05 - val_loss: 0.0636
# Epoch 28285/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2282e-05 - val_loss: 0.0636
# Epoch 28286/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.1255e-05 - val_loss: 0.0638
# Epoch 28287/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2262e-05 - val_loss: 0.0636
# Epoch 28288/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.2864e-05 - val_loss: 0.0637
# Epoch 28289/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1243e-05 - val_loss: 0.0637
# Epoch 28290/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2832e-05 - val_loss: 0.0636
# Epoch 28291/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2035e-05 - val_loss: 0.0638
# Epoch 28292/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.1806e-05 - val_loss: 0.0638
# Epoch 28293/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.1228e-05 - val_loss: 0.0637
# Epoch 28294/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3502e-05 - val_loss: 0.0638
# Epoch 28295/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.4679e-05 - val_loss: 0.0636
# Epoch 28296/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0323e-05 - val_loss: 0.0637
# Epoch 28297/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6610e-05 - val_loss: 0.0632
# Epoch 28298/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.4805e-05 - val_loss: 0.0626
# Epoch 28299/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0821e-04 - val_loss: 0.0639
# Epoch 28300/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8041e-05 - val_loss: 0.0637
# Epoch 28301/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.4749e-05 - val_loss: 0.0633
# Epoch 28302/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 3.9802e-05 - val_loss: 0.0639
# Epoch 28303/50000
# 2/2 [==============================] - 0s 40ms/step - loss: 3.4797e-05 - val_loss: 0.0638
# Epoch 28304/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.3853e-05 - val_loss: 0.0638
# Epoch 28305/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.9524e-05 - val_loss: 0.0642
# Epoch 28306/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.4521e-05 - val_loss: 0.0639
# Epoch 28307/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.7894e-05 - val_loss: 0.0638
# Epoch 28308/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.9379e-05 - val_loss: 0.0643
# Epoch 28309/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 5.8530e-05 - val_loss: 0.0638
# Epoch 28310/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.2621e-05 - val_loss: 0.0634
# Epoch 28311/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.9196e-05 - val_loss: 0.0641
# Epoch 28312/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 4.9195e-05 - val_loss: 0.0632
# Epoch 28313/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2157e-05 - val_loss: 0.0627
# Epoch 28314/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 5.5420e-05 - val_loss: 0.0640
# Epoch 28315/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.7204e-05 - val_loss: 0.0642
# Epoch 28316/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.7547e-05 - val_loss: 0.0636
# Epoch 28317/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 5.0723e-05 - val_loss: 0.0634
# Epoch 28318/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7441e-05 - val_loss: 0.0643
# Epoch 28319/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.0323e-05 - val_loss: 0.0637
# Epoch 28320/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 4.2484e-05 - val_loss: 0.0629
# Epoch 28321/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 5.3672e-05 - val_loss: 0.0641
# Epoch 28322/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.6123e-05 - val_loss: 0.0641
# Epoch 28323/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.7075e-05 - val_loss: 0.0635
# Epoch 28324/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.7733e-05 - val_loss: 0.0637
# Epoch 28325/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.7675e-05 - val_loss: 0.0638
# Epoch 28326/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2554e-05 - val_loss: 0.0640
# Epoch 28327/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.1576e-05 - val_loss: 0.0638
# Epoch 28328/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 3.7411e-05 - val_loss: 0.0636
# Epoch 28329/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.9746e-05 - val_loss: 0.0637
# Epoch 28330/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4992e-05 - val_loss: 0.0635
# Epoch 28331/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.1306e-05 - val_loss: 0.0635
# Epoch 28332/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.8848e-05 - val_loss: 0.0639
# Epoch 28333/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 4.7281e-05 - val_loss: 0.0636
# Epoch 28334/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.6408e-05 - val_loss: 0.0636
# Epoch 28335/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.9929e-05 - val_loss: 0.0634
# Epoch 28336/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1840e-05 - val_loss: 0.0634
# Epoch 28337/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.1074e-05 - val_loss: 0.0640
# Epoch 28338/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2923e-05 - val_loss: 0.0638
# Epoch 28339/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.2664e-05 - val_loss: 0.0635
# Epoch 28340/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.7060e-05 - val_loss: 0.0633
# Epoch 28341/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2641e-05 - val_loss: 0.0637
# Epoch 28342/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.2308e-05 - val_loss: 0.0638
# Epoch 28343/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 3.6855e-05 - val_loss: 0.0632
# Epoch 28344/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.6097e-05 - val_loss: 0.0642
# Epoch 28345/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8568e-05 - val_loss: 0.0646
# Epoch 28346/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.2493e-05 - val_loss: 0.0632
# Epoch 28347/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.3767e-05 - val_loss: 0.0639
# Epoch 28348/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.4279e-05 - val_loss: 0.0641
# Epoch 28349/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.7011e-05 - val_loss: 0.0633
# Epoch 28350/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1740e-05 - val_loss: 0.0638
# Epoch 28351/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1227e-05 - val_loss: 0.0642
# Epoch 28352/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.8036e-05 - val_loss: 0.0641
# Epoch 28353/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0934e-05 - val_loss: 0.0634
# Epoch 28354/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.5009e-05 - val_loss: 0.0633
# Epoch 28355/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.1693e-05 - val_loss: 0.0638
# Epoch 28356/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7354e-05 - val_loss: 0.0637
# Epoch 28357/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4488e-05 - val_loss: 0.0636
# Epoch 28358/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4980e-05 - val_loss: 0.0640
# Epoch 28359/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8345e-05 - val_loss: 0.0639
# Epoch 28360/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0144e-05 - val_loss: 0.0636
# Epoch 28361/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.9903e-05 - val_loss: 0.0641
# Epoch 28362/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.9967e-05 - val_loss: 0.0639
# Epoch 28363/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0944e-05 - val_loss: 0.0636
# Epoch 28364/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8519e-05 - val_loss: 0.0638
# Epoch 28365/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4991e-05 - val_loss: 0.0636
# Epoch 28366/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.1252e-05 - val_loss: 0.0636
# Epoch 28367/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.9048e-05 - val_loss: 0.0638
# Epoch 28368/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8083e-05 - val_loss: 0.0638
# Epoch 28369/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9862e-05 - val_loss: 0.0638
# Epoch 28370/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.7971e-05 - val_loss: 0.0637
# Epoch 28371/50000
# 2/2 [==============================] - 0s 40ms/step - loss: 2.6947e-05 - val_loss: 0.0640
# Epoch 28372/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.7269e-05 - val_loss: 0.0639
# Epoch 28373/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8202e-05 - val_loss: 0.0637
# Epoch 28374/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.5609e-05 - val_loss: 0.0637
# Epoch 28375/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6923e-05 - val_loss: 0.0639
# Epoch 28376/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.6256e-05 - val_loss: 0.0639
# Epoch 28377/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.6416e-05 - val_loss: 0.0637
# Epoch 28378/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5230e-05 - val_loss: 0.0637
# Epoch 28379/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9775e-05 - val_loss: 0.0642
# Epoch 28380/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8780e-05 - val_loss: 0.0640
# Epoch 28381/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.3795e-05 - val_loss: 0.0638
# Epoch 28382/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6162e-05 - val_loss: 0.0636
# Epoch 28383/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5843e-05 - val_loss: 0.0636
# Epoch 28384/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5855e-05 - val_loss: 0.0640
# Epoch 28385/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.8675e-05 - val_loss: 0.0638
# Epoch 28386/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.1481e-05 - val_loss: 0.0637
# Epoch 28387/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.5994e-05 - val_loss: 0.0639
# Epoch 28388/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4698e-05 - val_loss: 0.0639
# Epoch 28389/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5411e-05 - val_loss: 0.0637
# Epoch 28390/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7081e-05 - val_loss: 0.0637
# Epoch 28391/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3568e-05 - val_loss: 0.0639
# Epoch 28392/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.3129e-05 - val_loss: 0.0638
# Epoch 28393/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2722e-05 - val_loss: 0.0637
# Epoch 28394/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2989e-05 - val_loss: 0.0640
# Epoch 28395/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2871e-05 - val_loss: 0.0640
# Epoch 28396/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 2.7756e-05 - val_loss: 0.0637
# Epoch 28397/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 2.6178e-05 - val_loss: 0.0638
# Epoch 28398/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5907e-05 - val_loss: 0.0637
# Epoch 28399/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 3.0247e-05 - val_loss: 0.0637
# Epoch 28400/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.8817e-05 - val_loss: 0.0638
# Epoch 28401/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 4.8315e-05 - val_loss: 0.0637
# Epoch 28402/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 5.7140e-05 - val_loss: 0.0640
# Epoch 28403/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.3295e-05 - val_loss: 0.0637
# Epoch 28404/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 4.1984e-05 - val_loss: 0.0637
# Epoch 28405/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 7.9009e-05 - val_loss: 0.0636
# Epoch 28406/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.3522e-05 - val_loss: 0.0639
# Epoch 28407/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 6.8976e-05 - val_loss: 0.0646
# Epoch 28408/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 1.8971e-04 - val_loss: 0.0636
# Epoch 28409/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.0201e-04 - val_loss: 0.0640
# Epoch 28410/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 8.5132e-05 - val_loss: 0.0643
# Epoch 28411/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.7014e-04 - val_loss: 0.0633
# Epoch 28412/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.5336e-04 - val_loss: 0.0643
# Epoch 28413/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.7981e-04 - val_loss: 0.0648
# Epoch 28414/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.3593e-04 - val_loss: 0.0650
# Epoch 28415/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.0477e-04 - val_loss: 0.0649
# Epoch 28416/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 6.4162e-04 - val_loss: 0.0634
# Epoch 28417/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 4.0821e-04 - val_loss: 0.0652
# Epoch 28418/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0057e-04 - val_loss: 0.0654
# Epoch 28419/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.3216e-04 - val_loss: 0.0644
# Epoch 28420/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 6.0027e-04 - val_loss: 0.0658
# Epoch 28421/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0011 - val_loss: 0.0636
# Epoch 28422/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.8585e-04 - val_loss: 0.0658
# Epoch 28423/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0020 - val_loss: 0.0683
# Epoch 28424/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0011 - val_loss: 0.0615
# Epoch 28425/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 9.6691e-04 - val_loss: 0.0611
# Epoch 28426/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0014 - val_loss: 0.0711
# Epoch 28427/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0017 - val_loss: 0.0774
# Epoch 28428/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.0023 - val_loss: 0.0688
# Epoch 28429/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0016 - val_loss: 0.0691
# Epoch 28430/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0012 - val_loss: 0.0676
# Epoch 28431/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.0017 - val_loss: 0.0635
# Epoch 28432/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.0010 - val_loss: 0.0630
# Epoch 28433/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 9.1846e-04 - val_loss: 0.0653
# Epoch 28434/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 8.7711e-04 - val_loss: 0.0659
# Epoch 28435/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 7.6754e-04 - val_loss: 0.0636
# Epoch 28436/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 6.4368e-04 - val_loss: 0.0642
# Epoch 28437/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 7.0230e-04 - val_loss: 0.0673
# Epoch 28438/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 6.4030e-04 - val_loss: 0.0673
# Epoch 28439/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 5.7626e-04 - val_loss: 0.0646
# Epoch 28440/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 6.0065e-04 - val_loss: 0.0637
# Epoch 28441/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.3351e-04 - val_loss: 0.0637
# Epoch 28442/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.6864e-04 - val_loss: 0.0637
# Epoch 28443/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.5862e-04 - val_loss: 0.0635
# Epoch 28444/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 4.1819e-04 - val_loss: 0.0635
# Epoch 28445/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.2970e-04 - val_loss: 0.0643
# Epoch 28446/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8449e-04 - val_loss: 0.0641
# Epoch 28447/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.9721e-04 - val_loss: 0.0640
# Epoch 28448/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4310e-04 - val_loss: 0.0644
# Epoch 28449/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1595e-04 - val_loss: 0.0644
# Epoch 28450/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.1135e-04 - val_loss: 0.0642
# Epoch 28451/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8539e-04 - val_loss: 0.0639
# Epoch 28452/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.6221e-04 - val_loss: 0.0639
# Epoch 28453/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.4730e-04 - val_loss: 0.0645
# Epoch 28454/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.3176e-04 - val_loss: 0.0647
# Epoch 28455/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.3159e-04 - val_loss: 0.0648
# Epoch 28456/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.1057e-04 - val_loss: 0.0650
# Epoch 28457/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.1690e-04 - val_loss: 0.0646
# Epoch 28458/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 9.6522e-05 - val_loss: 0.0641
# Epoch 28459/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 9.6315e-05 - val_loss: 0.0641
# Epoch 28460/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 1.0234e-04 - val_loss: 0.0645
# Epoch 28461/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 8.8728e-05 - val_loss: 0.0646
# Epoch 28462/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 7.7525e-05 - val_loss: 0.0643
# Epoch 28463/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 8.9027e-05 - val_loss: 0.0642
# Epoch 28464/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 9.0176e-05 - val_loss: 0.0647
# Epoch 28465/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 8.1630e-05 - val_loss: 0.0649
# Epoch 28466/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 7.6924e-05 - val_loss: 0.0641
# Epoch 28467/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 7.4217e-05 - val_loss: 0.0638
# Epoch 28468/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 6.4747e-05 - val_loss: 0.0642
# Epoch 28469/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.2816e-05 - val_loss: 0.0645
# Epoch 28470/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.8542e-05 - val_loss: 0.0645
# Epoch 28471/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 5.6054e-05 - val_loss: 0.0642
# Epoch 28472/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.4542e-05 - val_loss: 0.0641
# Epoch 28473/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.1998e-05 - val_loss: 0.0645
# Epoch 28474/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.6253e-05 - val_loss: 0.0645
# Epoch 28475/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.3261e-05 - val_loss: 0.0641
# Epoch 28476/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.3064e-05 - val_loss: 0.0643
# Epoch 28477/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.9370e-05 - val_loss: 0.0647
# Epoch 28478/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.2722e-05 - val_loss: 0.0645
# Epoch 28479/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8402e-05 - val_loss: 0.0643
# Epoch 28480/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.9297e-05 - val_loss: 0.0646
# Epoch 28481/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.7128e-05 - val_loss: 0.0647
# Epoch 28482/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.5364e-05 - val_loss: 0.0644
# Epoch 28483/50000
# 2/2 [==============================] - 0s 39ms/step - loss: 3.6000e-05 - val_loss: 0.0644
# Epoch 28484/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4889e-05 - val_loss: 0.0646
# Epoch 28485/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.3546e-05 - val_loss: 0.0648
# Epoch 28486/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.2977e-05 - val_loss: 0.0646
# Epoch 28487/50000
# 2/2 [==============================] - 0s 40ms/step - loss: 3.4399e-05 - val_loss: 0.0644
# Epoch 28488/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.3470e-05 - val_loss: 0.0646
# Epoch 28489/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.2488e-05 - val_loss: 0.0646
# Epoch 28490/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.2723e-05 - val_loss: 0.0644
# Epoch 28491/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.1414e-05 - val_loss: 0.0645
# Epoch 28492/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0488e-05 - val_loss: 0.0647
# Epoch 28493/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.2117e-05 - val_loss: 0.0645
# Epoch 28494/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.0639e-05 - val_loss: 0.0644
# Epoch 28495/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.9662e-05 - val_loss: 0.0645
# Epoch 28496/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9849e-05 - val_loss: 0.0646
# Epoch 28497/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.0150e-05 - val_loss: 0.0645
# Epoch 28498/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.9359e-05 - val_loss: 0.0645
# Epoch 28499/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8580e-05 - val_loss: 0.0645
# Epoch 28500/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8631e-05 - val_loss: 0.0645
# Epoch 28501/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.8634e-05 - val_loss: 0.0645
# Epoch 28502/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.7864e-05 - val_loss: 0.0645
# Epoch 28503/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.7971e-05 - val_loss: 0.0645
# Epoch 28504/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7482e-05 - val_loss: 0.0645
# Epoch 28505/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.7433e-05 - val_loss: 0.0646
# Epoch 28506/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.7263e-05 - val_loss: 0.0646
# Epoch 28507/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.6759e-05 - val_loss: 0.0644
# Epoch 28508/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.6892e-05 - val_loss: 0.0645
# Epoch 28509/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6601e-05 - val_loss: 0.0646
# Epoch 28510/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6483e-05 - val_loss: 0.0645
# Epoch 28511/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6244e-05 - val_loss: 0.0644
# Epoch 28512/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.6761e-05 - val_loss: 0.0645
# Epoch 28513/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6035e-05 - val_loss: 0.0646
# Epoch 28514/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6055e-05 - val_loss: 0.0645
# Epoch 28515/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5702e-05 - val_loss: 0.0645
# Epoch 28516/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5882e-05 - val_loss: 0.0646
# Epoch 28517/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.5650e-05 - val_loss: 0.0645
# Epoch 28518/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.5472e-05 - val_loss: 0.0644
# Epoch 28519/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.5290e-05 - val_loss: 0.0645
# Epoch 28520/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5025e-05 - val_loss: 0.0645
# Epoch 28521/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5175e-05 - val_loss: 0.0645
# Epoch 28522/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.4910e-05 - val_loss: 0.0645
# Epoch 28523/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.4791e-05 - val_loss: 0.0645
# Epoch 28524/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4526e-05 - val_loss: 0.0645
# Epoch 28525/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4551e-05 - val_loss: 0.0645
# Epoch 28526/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4619e-05 - val_loss: 0.0645
# Epoch 28527/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.4556e-05 - val_loss: 0.0646
# Epoch 28528/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4776e-05 - val_loss: 0.0646
# Epoch 28529/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.4653e-05 - val_loss: 0.0645
# Epoch 28530/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4237e-05 - val_loss: 0.0645
# Epoch 28531/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.4414e-05 - val_loss: 0.0645
# Epoch 28532/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.4140e-05 - val_loss: 0.0645
# Epoch 28533/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4304e-05 - val_loss: 0.0645
# Epoch 28534/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4034e-05 - val_loss: 0.0646
# Epoch 28535/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3884e-05 - val_loss: 0.0645
# Epoch 28536/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.3765e-05 - val_loss: 0.0645
# Epoch 28537/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3639e-05 - val_loss: 0.0645
# Epoch 28538/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3705e-05 - val_loss: 0.0646
# Epoch 28539/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.3561e-05 - val_loss: 0.0645
# Epoch 28540/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3707e-05 - val_loss: 0.0645
# Epoch 28541/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3496e-05 - val_loss: 0.0646
# Epoch 28542/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3491e-05 - val_loss: 0.0646
# Epoch 28543/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3970e-05 - val_loss: 0.0645
# Epoch 28544/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3555e-05 - val_loss: 0.0645
# Epoch 28545/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.3528e-05 - val_loss: 0.0645
# Epoch 28546/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4117e-05 - val_loss: 0.0644
# Epoch 28547/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4256e-05 - val_loss: 0.0645
# Epoch 28548/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3854e-05 - val_loss: 0.0646
# Epoch 28549/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4322e-05 - val_loss: 0.0646
# Epoch 28550/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.4012e-05 - val_loss: 0.0647
# Epoch 28551/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3672e-05 - val_loss: 0.0647
# Epoch 28552/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.5009e-05 - val_loss: 0.0645
# Epoch 28553/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4580e-05 - val_loss: 0.0645
# Epoch 28554/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.4358e-05 - val_loss: 0.0645
# Epoch 28555/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.6471e-05 - val_loss: 0.0644
# Epoch 28556/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.4676e-05 - val_loss: 0.0646
# Epoch 28557/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4349e-05 - val_loss: 0.0646
# Epoch 28558/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3655e-05 - val_loss: 0.0644
# Epoch 28559/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5623e-05 - val_loss: 0.0646
# Epoch 28560/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.4409e-05 - val_loss: 0.0646
# Epoch 28561/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3771e-05 - val_loss: 0.0645
# Epoch 28562/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3577e-05 - val_loss: 0.0645
# Epoch 28563/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3745e-05 - val_loss: 0.0645
# Epoch 28564/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.3528e-05 - val_loss: 0.0645
# Epoch 28565/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.3296e-05 - val_loss: 0.0645
# Epoch 28566/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.3536e-05 - val_loss: 0.0646
# Epoch 28567/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3352e-05 - val_loss: 0.0644
# Epoch 28568/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.3495e-05 - val_loss: 0.0644
# Epoch 28569/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.3973e-05 - val_loss: 0.0645
# Epoch 28570/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3914e-05 - val_loss: 0.0646
# Epoch 28571/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2775e-05 - val_loss: 0.0645
# Epoch 28572/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3829e-05 - val_loss: 0.0644
# Epoch 28573/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.2467e-05 - val_loss: 0.0645
# Epoch 28574/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2943e-05 - val_loss: 0.0647
# Epoch 28575/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2604e-05 - val_loss: 0.0646
# Epoch 28576/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2712e-05 - val_loss: 0.0645
# Epoch 28577/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2403e-05 - val_loss: 0.0645
# Epoch 28578/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2718e-05 - val_loss: 0.0646
# Epoch 28579/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2312e-05 - val_loss: 0.0646
# Epoch 28580/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2818e-05 - val_loss: 0.0645
# Epoch 28581/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2359e-05 - val_loss: 0.0645
# Epoch 28582/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2501e-05 - val_loss: 0.0645
# Epoch 28583/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2257e-05 - val_loss: 0.0645
# Epoch 28584/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3354e-05 - val_loss: 0.0646
# Epoch 28585/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.4161e-05 - val_loss: 0.0645
# Epoch 28586/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2119e-05 - val_loss: 0.0644
# Epoch 28587/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4087e-05 - val_loss: 0.0646
# Epoch 28588/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.5058e-05 - val_loss: 0.0645
# Epoch 28589/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.2688e-05 - val_loss: 0.0645
# Epoch 28590/50000
# 2/2 [==============================] - 0s 40ms/step - loss: 2.7223e-05 - val_loss: 0.0648
# Epoch 28591/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.6614e-05 - val_loss: 0.0646
# Epoch 28592/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.3947e-05 - val_loss: 0.0645
# Epoch 28593/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.3015e-05 - val_loss: 0.0645
# Epoch 28594/50000
# 2/2 [==============================] - 0s 41ms/step - loss: 2.4032e-05 - val_loss: 0.0645
# Epoch 28595/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.3001e-05 - val_loss: 0.0644
# Epoch 28596/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2705e-05 - val_loss: 0.0645
# Epoch 28597/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2583e-05 - val_loss: 0.0646
# Epoch 28598/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 2.2435e-05 - val_loss: 0.0645
# Epoch 28599/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2441e-05 - val_loss: 0.0646
# Epoch 28600/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2259e-05 - val_loss: 0.0647
# Epoch 28601/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2281e-05 - val_loss: 0.0646
# Epoch 28602/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.2565e-05 - val_loss: 0.0645
# Epoch 28603/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.2508e-05 - val_loss: 0.0645
# Epoch 28604/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.2872e-05 - val_loss: 0.0645
# Epoch 28605/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.2407e-05 - val_loss: 0.0645
# Epoch 28606/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.3557e-05 - val_loss: 0.0645
# Epoch 28607/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.3202e-05 - val_loss: 0.0646
# Epoch 28608/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.3222e-05 - val_loss: 0.0644
# Epoch 28609/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.2152e-05 - val_loss: 0.0642
# Epoch 28610/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.4603e-05 - val_loss: 0.0646
# Epoch 28611/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.4497e-05 - val_loss: 0.0646
# Epoch 28612/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.2827e-05 - val_loss: 0.0644
# Epoch 28613/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5876e-05 - val_loss: 0.0647
# Epoch 28614/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.7002e-05 - val_loss: 0.0647
# Epoch 28615/50000
# ...
# 2/2 [==============================] - 0s 30ms/step - loss: 1.9518e-05 - val_loss: 0.0654
# Epoch 30524/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.9126e-05 - val_loss: 0.0653
# Epoch 30525/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.8984e-05 - val_loss: 0.0654
# Epoch 30526/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.9273e-05 - val_loss: 0.0654
# Epoch 30527/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.9618e-05 - val_loss: 0.0654
# Epoch 30528/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.9008e-05 - val_loss: 0.0654
# Epoch 30529/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9538e-05 - val_loss: 0.0653
# Epoch 30530/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9885e-05 - val_loss: 0.0654
# Epoch 30531/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.9206e-05 - val_loss: 0.0654
# Epoch 30532/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 1.9076e-05 - val_loss: 0.0653
# Epoch 30533/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.8831e-05 - val_loss: 0.0655
# Epoch 30534/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9383e-05 - val_loss: 0.0653
# Epoch 30535/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8809e-05 - val_loss: 0.0651
# Epoch 30536/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8918e-05 - val_loss: 0.0653
# Epoch 30537/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8808e-05 - val_loss: 0.0654
# Epoch 30538/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.8639e-05 - val_loss: 0.0654
# Epoch 30539/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8498e-05 - val_loss: 0.0654
# Epoch 30540/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8492e-05 - val_loss: 0.0654
# Epoch 30541/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.8360e-05 - val_loss: 0.0654
# Epoch 30542/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9112e-05 - val_loss: 0.0653
# Epoch 30543/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 1.8634e-05 - val_loss: 0.0654
# Epoch 30544/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8444e-05 - val_loss: 0.0654
# Epoch 30545/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.8518e-05 - val_loss: 0.0653
# Epoch 30546/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9427e-05 - val_loss: 0.0655
# Epoch 30547/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 1.9522e-05 - val_loss: 0.0653
# Epoch 30548/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 1.8644e-05 - val_loss: 0.0653
# Epoch 30549/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8847e-05 - val_loss: 0.0657
# Epoch 30550/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.9320e-05 - val_loss: 0.0654
# Epoch 30551/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.8892e-05 - val_loss: 0.0653
# Epoch 30552/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 1.8696e-05 - val_loss: 0.0654
# Epoch 30553/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 1.9257e-05 - val_loss: 0.0654
# Epoch 30554/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 1.9157e-05 - val_loss: 0.0653
# Epoch 30555/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 1.8682e-05 - val_loss: 0.0654
# Epoch 30556/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.0005e-05 - val_loss: 0.0655
# Epoch 30557/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 2.6481e-05 - val_loss: 0.0654
# Epoch 30558/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 6.3774e-05 - val_loss: 0.0654
# Epoch 30559/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 3.8338e-05 - val_loss: 0.0655
# Epoch 30560/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 2.9423e-05 - val_loss: 0.0653
# Epoch 30561/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 6.1985e-05 - val_loss: 0.0653
# Epoch 30562/50000
# 2/2 [==============================] - 0s 29ms/step - loss: 5.9644e-05 - val_loss: 0.0653
# Epoch 30563/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 7.0226e-05 - val_loss: 0.0653
# Epoch 30564/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 3.9852e-05 - val_loss: 0.0655
# Epoch 30565/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.8301e-05 - val_loss: 0.0656
# Epoch 30566/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.1420e-05 - val_loss: 0.0657
# Epoch 30567/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8524e-05 - val_loss: 0.0657
# Epoch 30568/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.6995e-05 - val_loss: 0.0653
# Epoch 30569/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.8595e-05 - val_loss: 0.0655
# Epoch 30570/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.5185e-05 - val_loss: 0.0652
# Epoch 30571/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.1955e-05 - val_loss: 0.0651
# Epoch 30572/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.5551e-05 - val_loss: 0.0658
# Epoch 30573/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.3707e-05 - val_loss: 0.0652
# Epoch 30574/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.4260e-05 - val_loss: 0.0654
# Epoch 30575/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.9146e-05 - val_loss: 0.0656
# Epoch 30576/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.2548e-05 - val_loss: 0.0650
# Epoch 30577/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4407e-05 - val_loss: 0.0654
# Epoch 30578/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8009e-05 - val_loss: 0.0655
# Epoch 30579/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6153e-05 - val_loss: 0.0651
# Epoch 30580/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5952e-05 - val_loss: 0.0654
# Epoch 30581/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.7552e-05 - val_loss: 0.0656
# Epoch 30582/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4750e-05 - val_loss: 0.0655
# Epoch 30583/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.4131e-05 - val_loss: 0.0654
# Epoch 30584/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.3151e-05 - val_loss: 0.0656
# Epoch 30585/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 2.3372e-05 - val_loss: 0.0655
# Epoch 30586/50000
# 2/2 [==============================] - 0s 36ms/step - loss: 2.6401e-05 - val_loss: 0.0650
# Epoch 30587/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.6361e-05 - val_loss: 0.0656
# Epoch 30588/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 2.4695e-05 - val_loss: 0.0657
# Epoch 30589/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.6044e-05 - val_loss: 0.0650
# Epoch 30590/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.2024e-05 - val_loss: 0.0653
# Epoch 30591/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.3905e-05 - val_loss: 0.0655
# Epoch 30592/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.1821e-05 - val_loss: 0.0652
# Epoch 30593/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.0837e-05 - val_loss: 0.0657
# Epoch 30594/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4602e-05 - val_loss: 0.0655
# Epoch 30595/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6602e-05 - val_loss: 0.0653
# Epoch 30596/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8366e-05 - val_loss: 0.0656
# Epoch 30597/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.3743e-05 - val_loss: 0.0655
# Epoch 30598/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.3904e-05 - val_loss: 0.0657
# Epoch 30599/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7589e-05 - val_loss: 0.0654
# Epoch 30600/50000
# 2/2 [==============================] - 0s 34ms/step - loss: 5.1372e-05 - val_loss: 0.0651
# Epoch 30601/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.8111e-05 - val_loss: 0.0657
# Epoch 30602/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.2410e-05 - val_loss: 0.0655
# Epoch 30603/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.6295e-05 - val_loss: 0.0650
# Epoch 30604/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.0992e-05 - val_loss: 0.0653
# Epoch 30605/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.8268e-05 - val_loss: 0.0650
# Epoch 30606/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.6697e-05 - val_loss: 0.0654
# Epoch 30607/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.0522e-05 - val_loss: 0.0659
# Epoch 30608/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.5368e-05 - val_loss: 0.0653
# Epoch 30609/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.7384e-05 - val_loss: 0.0652
# Epoch 30610/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.9719e-05 - val_loss: 0.0651
# Epoch 30611/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4801e-05 - val_loss: 0.0656
# Epoch 30612/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.2507e-05 - val_loss: 0.0659
# Epoch 30613/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.7547e-05 - val_loss: 0.0653
# Epoch 30614/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7279e-05 - val_loss: 0.0654
# Epoch 30615/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.2781e-05 - val_loss: 0.0655
# Epoch 30616/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.5290e-05 - val_loss: 0.0656
# Epoch 30617/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.8860e-05 - val_loss: 0.0656
# Epoch 30618/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0137e-05 - val_loss: 0.0654
# Epoch 30619/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6039e-05 - val_loss: 0.0655
# Epoch 30620/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 2.6652e-05 - val_loss: 0.0653
# Epoch 30621/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.6816e-05 - val_loss: 0.0655
# Epoch 30622/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.0964e-05 - val_loss: 0.0658
# Epoch 30623/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.6448e-05 - val_loss: 0.0655
# Epoch 30624/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8740e-05 - val_loss: 0.0654
# Epoch 30625/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.1753e-05 - val_loss: 0.0654
# Epoch 30626/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4515e-05 - val_loss: 0.0655
# Epoch 30627/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.7344e-05 - val_loss: 0.0653
# Epoch 30628/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.8907e-05 - val_loss: 0.0653
# Epoch 30629/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.9779e-05 - val_loss: 0.0654
# Epoch 30630/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.6497e-05 - val_loss: 0.0644
# Epoch 30631/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.4188e-05 - val_loss: 0.0648
# Epoch 30632/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.8206e-05 - val_loss: 0.0663
# Epoch 30633/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.0968e-05 - val_loss: 0.0656
# Epoch 30634/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.5042e-05 - val_loss: 0.0651
# Epoch 30635/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.9469e-05 - val_loss: 0.0657
# Epoch 30636/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.9004e-05 - val_loss: 0.0652
# Epoch 30637/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 4.2814e-05 - val_loss: 0.0653
# Epoch 30638/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.7648e-05 - val_loss: 0.0659
# Epoch 30639/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.6387e-05 - val_loss: 0.0656
# Epoch 30640/50000
# 2/2 [==============================] - 0s 47ms/step - loss: 3.1848e-05 - val_loss: 0.0657
# Epoch 30641/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.5972e-05 - val_loss: 0.0659
# Epoch 30642/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.8661e-05 - val_loss: 0.0654
# Epoch 30643/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4585e-05 - val_loss: 0.0655
# Epoch 30644/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.1115e-05 - val_loss: 0.0657
# Epoch 30645/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 2.8222e-05 - val_loss: 0.0653
# Epoch 30646/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 2.8719e-05 - val_loss: 0.0654
# Epoch 30647/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.2005e-05 - val_loss: 0.0653
# Epoch 30648/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4027e-05 - val_loss: 0.0655
# Epoch 30649/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 2.7037e-05 - val_loss: 0.0654
# Epoch 30650/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.9115e-05 - val_loss: 0.0650
# Epoch 30651/50000
# 2/2 [==============================] - 0s 38ms/step - loss: 3.4994e-05 - val_loss: 0.0657
# Epoch 30652/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.8517e-05 - val_loss: 0.0654
# Epoch 30653/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.3666e-05 - val_loss: 0.0653
# Epoch 30654/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.2831e-05 - val_loss: 0.0665
# Epoch 30655/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 5.3422e-05 - val_loss: 0.0653
# Epoch 30656/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4327e-05 - val_loss: 0.0648
# Epoch 30657/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 4.3216e-05 - val_loss: 0.0663
# Epoch 30658/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.9527e-05 - val_loss: 0.0654
# Epoch 30659/50000
# 2/2 [==============================] - 0s 33ms/step - loss: 4.5253e-05 - val_loss: 0.0654
# Epoch 30660/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.8973e-05 - val_loss: 0.0658
# Epoch 30661/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 4.2171e-05 - val_loss: 0.0650
# Epoch 30662/50000
# 2/2 [==============================] - 0s 37ms/step - loss: 5.1543e-05 - val_loss: 0.0660
# Epoch 30663/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 7.9762e-05 - val_loss: 0.0652
# Epoch 30664/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 6.6454e-05 - val_loss: 0.0655
# Epoch 30665/50000
# 2/2 [==============================] - 0s 30ms/step - loss: 7.6905e-05 - val_loss: 0.0658
# Epoch 30666/50000
# 2/2 [==============================] - 0s 35ms/step - loss: 7.2115e-05 - val_loss: 0.0649
# Epoch 30667/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 5.4699e-05 - val_loss: 0.0658
# Epoch 30668/50000
# 2/2 [==============================] - 0s 32ms/step - loss: 6.4335e-05 - val_loss: 0.0654
# Epoch 30669/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 8.1227e-05 - val_loss: 0.0655
# Epoch 30670/50000
# 2/2 [==============================] - 0s 31ms/step - loss: 6.4066e-05 - val_loss: 0.0655
# Epoch 30671/50000

# %% [markdown]
# ## Test de reconstruction d'images pour le test
#
# ---

# %%
image = resize_and_convert_to_gray('Kodak/kodim12.png')
image= np.expand_dims(image, axis=0)
reconstructed_images = autoencoder.predict(image)
output_folder = 'compressed_images/'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

for i, img_array in enumerate(reconstructed_images):
    img = Image.fromarray((img_array.squeeze() * 255).astype(np.uint8))
    img.save(os.path.join(output_folder, f'image_compressee_{i+1:02d}.png'))

# %% [markdown]
# ## Fonctions

# %%
def encoding(image_path, enc):
  image = resize_and_convert_to_gray(image_path)
  image = np.expand_dims(image, axis=0)
  encoded_image = enc.predict(image)
  #encoded_vector = encoded_image[0]
  #print(encoded_vector)
  #return encoded_vector
  return encoded_image

# %%
def decoding(output_path,dec, y):
  print(y)
  #encoded_vector_batch = np.expand_dims(y, axis=0)
  #reconstructed_data = dec.predict(encoded_vector_batch)
  reconstructed_data = dec.predict(y)
  image_finale =  reconstructed_data[0]
  #print(image_finale)
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  img = Image.fromarray((image_finale.squeeze() * 255).astype(np.uint8))
  img.save(os.path.join(output_path, f'image_compressee.png'))
  #convert_to_gray_and_save(image_finale.squeeze(), output_path)

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Encodage

# %%
encoded_vector = encoding('Kodak/kodim04.png', encoder)

# %% [markdown]
# Test

# %%
encoded_vector.shape

# %%
encoded_vector.dtype

# %% [markdown]
# ### Decodage

# %%
decoding("image_test/",decoder, encoded_vector)

# %%
print(encoded_vector)
